# %%
import os
import sys
import pandas as pd
import numpy as np

#path1='F:/trec-RTS/14417'

#path='C:/Users/lenovo/Google Drive/PHD share folder/paper/trec experiment/rishabh/23417/grid'
#path='C:/Users/lenovo/Google Drive/PHD share folder/paper/trec experiment/rishabh/9617/bm25/grid'
#path='C:/Users/lenovo/Google Drive/PHD share folder/paper/trec experiment/rishabh/9617/lm/grid'
path='C:/Users/lenovo/Google Drive/PHD share folder/paper/trec experiment/rishabh/14617/3000/grid'
#path='C:/Users/lenovo/Google Drive/PHD share folder/paper/trec experiment/rishabh/6617/0.2/grid'



os.chdir(path)
#profile=['MB226','MB229','MB230']
#profile=['MB258']
profile=['MB226','MB229','MB230','MB239','MB254','MB256','MB258','MB265','MB267','MB276','MB286','MB319','MB320','MB332','MB351',
'MB358','MB361','MB362','MB363','MB365','MB371','MB377','MB381','MB382','MB391','MB392','MB409','MB410','MB414','MB419',  
'MB420','MB425','MB431','MB436','MB438','MB440','RTS1','RTS10','RTS13','RTS14','RTS19','RTS2','RTS21','RTS24','RTS25',
'RTS27','RTS28','RTS31','RTS32','RTS35','RTS36','RTS37','RTS4','RTS43','RTS5','RTS6']

# %%
grid = pd.read_csv('rdata_new.txt',sep=' ',header=None)
grid.columns=['profile','ndcg1','ndcg0','tmin','tmax','lamda']
#grid.columns=['profile','ndcg1','ndcg0','tmin','tmax']

grid.head()
sgrid=grid.sort_values(['profile','ndcg1','ndcg0'],ascending=[True,True,True])
sgrid=sgrid.reset_index(drop=True)
sgrid.head()
sgrid.to_csv("rdata_newcsv.csv",index=False)
#grid.info()

# %%
def param(df,topic) :
    maxn1=0
    maxi=0
    cndcg0=0
    mndcg0=0
    for i, row in df.iterrows():
        s = row['ndcg1']
        cndcg0=row['ndcg0']
        
        if(s>maxn1):
            maxn1=s
            mndcg0=cndcg0
            maxi = i
        if(s==maxn1):
            if(cndcg0>mndcg0):
                maxi=i
    return maxi

# %%
fgold1=open('gold1L-new.txt','w')
#fgoldboth=open('goldboth.txt','w')
for i,p in enumerate(profile):
    qn=sgrid[(sgrid['profile'] == p)]
    qn=qn.reset_index(drop=True)
   # qn.info()
    indx =param(qn,p)
    
    temp1=qn.ix[indx,'ndcg1']
    #ndcg1_dt[p]= {p1:temp}
    temp2= qn.ix[indx,'ndcg0']
    temp3= qn.ix[indx,'tmin']
    temp4= qn.ix[indx,'tmax']
    
    temp5= qn.ix[indx,'lamda']
    tempstr = p + ' ' + str(temp1)+' ' + str(temp2)+' '+ str(temp3)+' ' + str(temp4)+' ' + str(temp5)+'\n'
    
    #tempstr = p + ' ' + str(temp1)+' ' + str(temp2)+' '+ str(temp3)+' ' + str(temp4)+'\n'
    
    fgold1.write(tempstr)    
    
   

fgold1.close()

# %%
p
# Out:
# 'RTS194'

# %%
fgold1.close()

# %%
### check 2 file
path1='C:/Users/lenovo/Google Drive/PHD share folder/paper/trec experiment/rishabh/23417/grid'
#path='C:/Users/lenovo/Google Drive/PHD share folder/paper/trec experiment/rishabh/9617/bm25/grid'
path2='C:/Users/lenovo/Google Drive/PHD share folder/paper/trec experiment/rishabh/9617/lm/grid'
os.chdir(path1)
ndcg1_df1 = pd.read_csv('gold1L.txt',sep=' ',header=None)
ndcg1_df1.columns=['profile','ndcg1','ndcg0','tmin','tmax','lamda']

ndcg0_df1 = pd.read_csv('gold0L.txt',sep=' ',header=None)
ndcg0_df1.columns=['profile','ndcg1','ndcg0','tmin','tmax','lamda']

ndcgboth_df1 = pd.read_csv('goldbothL.txt',sep=' ',header=None)
ndcgboth_df1.columns=['profile','ndcg1','ndcg0','tmin','tmax','lamda']

os.chdir(path2)
ndcg1_df2 = pd.read_csv('gold1L.txt',sep=' ',header=None)
ndcg1_df2.columns=['profile','ndcg1','ndcg0','tmin','tmax','lamda']

ndcg0_df2 = pd.read_csv('gold0L.txt',sep=' ',header=None)
ndcg0_df2.columns=['profile','ndcg1','ndcg0','tmin','tmax','lamda']

ndcgboth_df2 = pd.read_csv('goldbothL.txt',sep=' ',header=None)
ndcgboth_df2.columns=['profile','ndcg1','ndcg0','tmin','tmax','lamda']

ndf1 =pd.merge(ndcg1_df2,ndcg1_df2,how='inner',on=['profile'])
ndf0 =pd.merge(ndcg0_df2,ndcg0_df2,how='inner',on=['profile'])
ndfboth=pd.merge(ndcgboth_df2,ndcgboth_df2,how='inner',on=['profile'])

# %%
ndfboth
# Out:
#    profile  ndcg1_x  ndcg0_x  tmin_x  tmax_x  lamda_x  ndcg1_y  ndcg0_y  \
# 0    MB226   0.7000   0.0000      20      30      0.2   0.7000   0.0000
# 1    MB229   0.0650   0.0650      16      23      0.1   0.0650   0.0650
# 2    MB230   0.9000   0.0000      20      30      0.2   0.9000   0.0000
# 3    MB239   0.8264   0.0264      17      26      0.2   0.8264   0.0264
# 4    MB254   0.7000   0.0000      20      30      0.2   0.7000   0.0000
# 5    MB256   0.1848   0.0848      20      29      0.2   0.1848   0.0848
# 6    MB258   0.2704   0.0704      18      26      0.1   0.2704   0.0704
# 7    MB265   0.3000   0.0000      20      30      0.2   0.3000   0.0000
# 8    MB267   0.2399   0.2399      17      21      0.1   0.2399   0.2399
# 9    MB276   0.1582   0.0582      17      26      0.1   0.1582   0.0582
# 10   MB286   0.1000   0.0000      20      30      0.2   0.1000   0.0000
# 11   MB319   0.3456   0.2456      18      26      0.2   0.3456   0.2456
# ...
